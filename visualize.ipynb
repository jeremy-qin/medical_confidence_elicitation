# %%
import pandas as pd

# %%
df = pd.read_parquet("results/medqa_gpt-3.5-turbo_base_12_01:26:22.parquet")

# %%
df.head()
# Out:
#                                            Questions Difficulty Score  \
# 0  A 72-year-old woman presents to her primary ca...              [5]
# 1  A 14-year-old girl with a BMI of 17 complains ...              [4]
# 2  A 29-year-old woman (gravida 2, para 1) presen...              [4]
# 3  A 28-year-old woman who was recently hired at ...              [4]
# 4  A 5-month-old male infant is brought to the ph...              [6]
#
#    Mean Difficulty Score Correct Answers Majority Predicted Answer  \
# 0                    5.0               D                         E
# 1                    4.0               C                         B
# 2                    4.0               B                         E
# 3                    4.0               C                         C
# 4                    6.0               E                         C
#
#   All Predicted Answers Final Prediction  Consistency Confidence  \
# 0                   [E]                E                     1.0
# ...
